# %% [markdown]
# <a href="https://colab.research.google.com/github/feomedeirosdev/ml-courseira/blob/main/004_naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from yellowbrick.classifier import ConfusionMatrix

# %%
df = pd.read_csv('/content/drive/MyDrive/CursoIA/3.Algoritmos de Machine Learning/insurance.csv', keep_default_na=False)
df
# Out:
#        Unnamed: 0  GoodStudent         Age    SocioEcon RiskAversion  \
# 0               1        False       Adult        Prole  Adventurous
# 1               2        False      Senior        Prole     Cautious
# 2               3        False      Senior  UpperMiddle   Psychopath
# 3               4        False  Adolescent       Middle       Normal
# 4               5        False  Adolescent        Prole       Normal
# ...           ...          ...         ...          ...          ...
# 19995       19996        False       Adult        Prole  Adventurous
# 19996       19997        False       Adult       Middle       Normal
# 19997       19998        False      Senior  UpperMiddle       Normal
# 19998       19999        False       Adult       Middle       Normal
# 19999       20000        False       Adult       Middle       Normal
#
#       VehicleYear ThisCarDam RuggedAuto  Accident    MakeModel  ... HomeBase  \
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)
target = 'Accident'
features = [
    'GoodStudent',
    'Age',
    'SocioEcon',
    'RiskAversion',
    'VehicleYear',
    'ThisCarDam',
    'RuggedAuto',
    'MakeModel',
    'DrivQuality',
    'Mileage',
    'Antilock',
    'DrivingSkill',
    'SeniorTrain',
    'ThisCarCost',
    'Theft',
    'CarValue',
    'HomeBase',
    'AntiTheft',
    'PropCost',
    'OtherCarCost',
    'OtherCar',
    'MedCost',
    'Cushioning',
    'Airbag',
    'ILiCost',
    'DrivHist']

X = df[features]
y = df[target]

# %%
y
# Out:
# 0            Mild
# 1            None
# 2            None
# 3            None
# 4        Moderate
#            ...
# 19995        Mild
# 19996        None
# 19997        None
# 19998        None
# 19999        None
# Name: Accident, Length: 20000, dtype: object

# %%
for col in list(X.columns):
    if X[col].dtype in ['object']:
        le_X = LabelEncoder()
        X[col] = le_X.fit_transform(X[col])
# Out:
# <ipython-input-134-1209721905>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le_X.fit_transform(X[col])
# <ipython-input-134-1209721905>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le_X.fit_transform(X[col])
# <ipython-input-134-1209721905>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# le_y = LabelEncoder()
# y = le_y.fit_transform(y)
# # y = pd.Series(y)
y
# Out:
# 0            Mild
# 1            None
# 2            None
# 3            None
# 4        Moderate
#            ...
# 19995        Mild
# 19996        None
# 19997        None
# 19998        None
# 19999        None
# Name: Accident, Length: 20000, dtype: object

# %%
X
# Out:
#        GoodStudent  Age  SocioEcon  RiskAversion  VehicleYear  ThisCarDam  \
# 0            False    1          1             0            1           1
# 1            False    2          1             1            0           2
# 2            False    2          2             3            0           2
# 3            False    0          0             2            1           2
# 4            False    0          1             2            1           1
# ...            ...  ...        ...           ...          ...         ...
# 19995        False    1          1             0            1           0
# 19996        False    1          0             2            1           2
# 19997        False    2          2             2            0           2
# 19998        False    1          0             2            1           2
# 19999        False    1          0             2            1           2
#
#        RuggedAuto  MakeModel  DrivQuality  Mileage  ...  HomeBase  AntiTheft  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
nb_pred = nb.predict(X_test)

# %%
nb_acc = accuracy_score(y_test, nb_pred)
nb_precision = precision_score(y_test, nb_pred, average='weighted')
nb_recall = recall_score(y_test, nb_pred, average='weighted')
nb_f1 = f1_score(y_test, nb_pred, average='weighted')

# %%
print(f'Accuracy: {nb_acc}')
print(f'Precision: {nb_precision}')
print(f'Recall: {nb_recall}')
print(f'F1: {nb_f1}')
# Out:
# Accuracy: 0.8425
# Precision: 0.885112335401402
# Recall: 0.8425
# F1: 0.8177528011133723

# %%
report = classification_report(y_test, nb_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         Mild       0.64      0.79      0.71       517
#     Moderate       0.33      0.66      0.44       476
#         None       0.98      1.00      0.99      4298
#       Severe       0.85      0.06      0.11       709
#
#     accuracy                           0.84      6000
#    macro avg       0.70      0.63      0.56      6000
# weighted avg       0.89      0.84      0.82      6000
